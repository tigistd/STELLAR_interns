# %%
import detrend as dt
import matplotlib.pyplot as plt
from astropy.table import Table
import numpy as np

# %%
star = [177256886]

# %%
lc, stats = dt.detrend_data(star)

# %%
print(stats)
# Out:
# [[177256886 177256886 177256886 177256886 177256886 177256886 177256886
#   177256886 177256886 177256886 177256886]
#  [        1         3         4         5         6         7         8
#           9        10        11        13]]

# %%
lc_idx = np.arange(0,len(lc),1)
mytable = Table([lc_idx, stats[0],stats[1]], names =('lc_idx','star_id','sector'))
mytable
# Out:
# <Table length=11>
# lc_idx  star_id  sector
# int64    int32   int32
# ------ --------- ------
#      0 177256886      1
#      1 177256886      3
#      2 177256886      4
#      3 177256886      5
#      4 177256886      6
#      5 177256886      7
#      6 177256886      8
#      7 177256886      9
#      8 177256886     10
#      9 177256886     11
#     10 177256886     13

# %%
lc
# Out:
# [TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886),
#  TessLightCurve(TICID: 177256886)]

# %%
len(lc)
# Out:
# 11

# %%
lc[0].scatter()
plt.axvline(1348, color='r',linestyle='--')
plt.axvline(1349.5, color='r',linestyle='--')

# %%
lc[1].scatter()
plt.axvline(1394.5, color='r',linestyle='--')
plt.axvline(1395.5, color='r',linestyle='--')

# %%
lc[2].scatter()
plt.axvline(1422.9, color='r',linestyle='--')
plt.axvline(1423.5, color='r',linestyle='--')

# %%
lc[3].scatter()
plt.axvline(1463.8, color='r',linestyle='--')
plt.axvline(1464.4, color='r',linestyle='--')

# %%
lc[4].scatter()

# %%
lc[5].scatter()

# %%
lc[6].scatter()
plt.axvline(1518, color='r',linestyle='--')
plt.axvline(1517.4, color='r',linestyle='--')

# %%
lc[7].scatter()

# %%
lc[8].scatter()

# %%
lc[9].scatter()

# %%
lc[10].scatter()
