# %%
import detrend as dt
import matplotlib.pyplot as plt

# %%
star = [176872276]

# %%
lc, stats = dt.detrend_data(star)

# %%
print(stats)
# Out:
# [[176872276 176872276 176872276 176872276 176872276 176872276 176872276
#   176872276 176872276 176872276 176872276 176872276]
#  [        1         2         3         4         6         7         8
#           9        10        11        12        13]]

# %%
lc
# Out:
# [TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276)]

# %%
lc[0].scatter()
plt.axvline(1348.5, color='r',linestyle='--')
plt.axvline(1349.35, color='r',linestyle='--')

# %%
len(lc)
# Out:
# 12

# %%
lc[1].scatter()
plt.axvline(1366, color='r',linestyle='--')
plt.axvline(1367.3, color='r',linestyle='--')

# %%
lc[1].scatter()

# %%
lc[2].scatter()
plt.axvline(1395, color='r',linestyle='--')
plt.axvline(1395.45, color='r',linestyle='--')

# %%
lc[4].scatter()
plt.axvline(1478.5, color='r',linestyle='--')
plt.axvline(1478.1, color='r',linestyle='--')

# %%
lc[5].scatter()

# %%
lc[6].scatter()
plt.axvline(1518.35, color='r',linestyle='--')
plt.axvline(1518, color='r',linestyle='--')

# %%
lc[7].scatter()
plt.axvline(1568.35, color='r',linestyle='--')
plt.axvline(1568.6, color='r',linestyle='--')

# %%
lc[8].scatter()
plt.axvline(1584.8, color='r',linestyle='--')
plt.axvline(1584.1, color='r',linestyle='--')

# %%
lc[9].scatter()
plt.axvline(1609.5, color='r',linestyle='--')
plt.axvline(1609.8, color='r',linestyle='--')

# %%
lc[10].scatter()
plt.axhline(4040, color='b',linestyle='--')
plt.axhline(4106, color='b',linestyle='--')
stats
# Out:
# array([[176872276, 176872276, 176872276, 176872276, 176872276, 176872276,
#         176872276, 176872276, 176872276, 176872276, 176872276, 176872276],
#        [        1,         2,         3,         4,         6,         7,
#                 8,         9,        10,        11,        12,        13]],
#       dtype=int32)

# %%
lc[11].scatter()
#plt.axvline(1669.8, color='r',linestyle='--')
#plt.axvline(1668.6, color='r',linestyle='--')
